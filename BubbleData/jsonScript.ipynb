# %%
import json
import collections

# %%
with open('lecsections.json') as f:
    data = json.load(f)
print(data)
# Out:
# [{'name': 'ACCT', 'Code': 321, 'data': [{'value': 22}]}, {'name': 'ACCT', 'Code': 501, 'data': [{'value': 8}]}, {'name': 'ACWR', 'Code': 101, 'data': [{'value': 20}]}, {'name': 'ACCT', 'Code': 201, 'data': [{'value': 94}]}, {'name': 'ACCT', 'Code': 202, 'data': [{'value': 53}]}, {'name': 'ACWR', 'Code': 103, 'data': [{'value': 17}]}, {'name': 'ACWR', 'Code': 104, 'data': [{'value': 15}]}, {'name': 'ALIS', 'Code': 100, 'data': [{'value': 26}]}, {'name': 'ACWR', 'Code': 106, 'data': [{'value': 16}]}, {'name': 'ARBC', 'Code': 201, 'data': [{'value': 7}]}, {'name': 'ARBC', 'Code': 202, 'data': [{'value': 21}]}, {'name': 'ARBC', 'Code': 301, 'data': [{'value': 14}]}, {'name': 'ARHA', 'Code': 201, 'data': [{'value': 19}]}, {'name': 'ARHA', 'Code': 315, 'data': [{'value': 17}]}, {'name': 'ARHA', 'Code': 318, 'data': [{'value': 1}]}, {'name': 'ACWR', 'Code': 107, 'data': [{'value': 11}]}, {'name': 'ARHA', 'Code': 407, 'data': [{'value': 11}]}, {'name': 'ARHA', 'Code': 422, 'data': [{'value': 25}]}, {'name': 'ARHA', 'Code': 461, 'data': [{'value': 15}]}, {'name': 'ARHA', 'Code': 502, 'data': [{'value': 33}]}, {'name': 'ARHA', 'Code': 526, 'data': [{'value': 19}]}, {'name': 'ARHA', 'Code': 527, 'data': [{'value': 18}]}, {'name': 'ARHA', 'Code': 550, 'data': [{'value': 7}]}, {'name': 'ARTS', 'Code': 201, 'data': [{'value': 68}]}, {'name': 'ARTS', 'Code': 350, 'data': [{'value': 72}]}, {'name': 'ASIU', 'Code': 100, 'data': [{'value': 7}]}, {'name': 'ASIU', 'Code': 102, 'data': [{'value': 8}]}, {'name': 'ASIU', 'Code': 104, 'data': [{'value': 10}]}, {'name': 'ASIU', 'Code': 115, 'data': [{'value': 1}]}, {'name': 'ASIU', 'Code': 118, 'data': [{'value': 20}]}, {'name': 'ASIU', 'Code': 121, 'data': [{'value': 27}]}, {'name': 'BUSA', 'Code': 499, 'data': [{'value': 23}]}, {'name': 'ASIU', 'Code': 109, 'data': [{'value': 12}]}, {'name': 'ASIU', 'Code': 111, 'data': [{'value': 7}]}, {'name': 'CHBI', 'Code': 201, 'data': [{'value': 21}]}, {'name': 'CHBI', 'Code': 300, 'data': [{'value': 62}]}, {'name': 'CHBI', 'Code': 301, 'data': [{'value': 101}]}, {'name': 'CHBI', 'Code': 302, 'data': [{'value': 1}]}, {'name': 'CHBI', 'Code': 303, 'data': [{'value': 16}]}, {'name': 'CHBI', 'Code': 402, 'data': [{'value': 25}]}, {'name': 'CHBI', 'Code': 403, 'data': [{'value': 16}]}, {'name': 'CHBI', 'Code': 405, 'data': [{'value': 37}]}, {'name': 'CHBI', 'Code': 415, 'data': [{'value': 41}]}, {'name': 'CHBI', 'Code': 418, 'data': [{'value': 45}]}, {'name': 'CHBI', 'Code': 501, 'data': [{'value': 10}]}, {'name': 'CHBI', 'Code': 502, 'data': [{'value': 20}]}, {'name': 'CHBI', 'Code': 510, 'data': [{'value': 18}]}, {'name': 'CHEM', 'Code': 101, 'data': [{'value': 17}]}, {'name': 'CHEM', 'Code': 103, 'data': [{'value': 1}]}, {'name': 'CHEM', 'Code': 201, 'data': [{'value': 18}]}, {'name': 'CHEM', 'Code': 206, 'data': [{'value': 19}]}, {'name': 'CHBI', 'Code': 503, 'data': [{'value': 15}]}, {'name': 'CHEM', 'Code': 301, 'data': [{'value': 5}]}, {'name': 'CHEM', 'Code': 303, 'data': [{'value': 31}]}, {'name': 'CHEM', 'Code': 502, 'data': [{'value': 13}]}, {'name': 'CHEM', 'Code': 504, 'data': [{'value': 21}]}, {'name': 'CHEM', 'Code': 515, 'data': [{'value': 24}]}, {'name': 'CHIN', 'Code': 202, 'data': [{'value': 4}]}, {'name': 'CMKT', 'Code': 501, 'data': [{'value': 38}]}, {'name': 'COMP', 'Code': 110, 'data': [{'value': 31}]}, {'name': 'CHEM', 'Code': 410, 'data': [{'value': 27}]}, {'name': 'CMSE', 'Code': 501, 'data': [{'value': 21}]}, {'name': 'COMP', 'Code': 111, 'data': [{'value': 5}]}, {'name': 'COMP', 'Code': 130, 'data': [{'value': 19}]}, {'name': 'CPAP', 'Code': 100, 'data': [{'value': 93}]}, {'name': 'COMP', 'Code': 131, 'data': [{'value': 76}]}, {'name': 'COMP', 'Code': 198, 'data': [{'value': 12}]}, {'name': 'COMP', 'Code': 303, 'data': [{'value': 43}]}, {'name': 'COMP', 'Code': 317, 'data': [{'value': 26}]}, {'name': 'COMP', 'Code': 442, 'data': [{'value': 31}]}, {'name': 'COMM', 'Code': 202, 'data': [{'value': 13}]}, {'name': 'COMP', 'Code': 450, 'data ...

# %%
with open('subjects.json') as f:
    subjects = json.load(f)
    
print(subjects)
# Out:
# [{'name': 'ACCT'}, {'name': 'ACWR'}, {'name': 'ALIS'}, {'name': 'ARBC'}, {'name': 'ARHA'}, {'name': 'ARTS'}, {'name': 'ASIU'}, {'name': 'BUSA'}, {'name': 'CHBI'}, {'name': 'CHEM'}, {'name': 'CHIN'}, {'name': 'CMKT'}, {'name': 'CMSE'}, {'name': 'COMM'}, {'name': 'COMP'}, {'name': 'CPAP'}, {'name': 'CSHS'}, {'name': 'DASC'}, {'name': 'DTES'}, {'name': 'ECIR'}, {'name': 'ECON'}, {'name': 'EFIN'}, {'name': 'ELC'}, {'name': 'ELEC'}, {'name': 'ENGR'}, {'name': 'EQUR'}, {'name': 'ETHC'}, {'name': 'EXCH'}, {'name': 'FREN'}, {'name': 'GERM'}, {'name': 'GREK'}, {'name': 'HIST'}, {'name': 'HUMS'}, {'name': 'INDR'}, {'name': 'INTL'}, {'name': 'ISP'}, {'name': 'ITAL'}, {'name': 'LANG'}, {'name': 'LATN'}, {'name': 'LAW'}, {'name': 'LITR'}, {'name': 'MASE'}, {'name': 'MATH'}, {'name': 'MAVA'}, {'name': 'MBGE'}, {'name': 'MECH'}, {'name': 'MEDI'}, {'name': 'MFIN'}, {'name': 'MGIS'}, {'name': 'MGMT'}, {'name': 'MKTG'}, {'name': 'NURS'}, {'name': 'OPSM'}, {'name': 'PHIL'}, {'name': 'PHYS'}, {'name': 'PSYC'}, {'name': 'QMBU'}, {'name': 'RUSS'}, {'name': 'SCIE'}, {'name': 'SOCI'}, {'name': 'SOSC'}, {'name': 'SPAN'}, {'name': 'TECH'}, {'name': 'TLIT'}, {'name': 'TURK'}, {'name': 'UNIV'}]

# %%
import pandas as pd

df = pd.DataFrame(subjects)
df.head(10)
# Out:
#    name
# 0  ACCT
# 1  ACWR
# 2  ALIS
# 3  ARBC
# 4  ARHA
# 5  ARTS
# 6  ASIU
# 7  BUSA
# 8  CHBI
# 9  CHEM

# %%
df['data']=''
for i in range(0, len(df)):
    df['data'][i] = []
df.head(10)
# Out:
#    name data
# 0  ACCT   []
# 1  ACWR   []
# 2  ALIS   []
# 3  ARBC   []
# 4  ARHA   []
# 5  ARTS   []
# 6  ASIU   []
# 7  BUSA   []
# 8  CHBI   []
# 9  CHEM   []

# %%
df2 = pd.DataFrame(data)
df2.head(10)
# Out:
#    Code             data  name
# 0   321  [{'value': 22}]  ACCT
# 1   501   [{'value': 8}]  ACCT
# 2   101  [{'value': 20}]  ACWR
# 3   201  [{'value': 94}]  ACCT
# 4   202  [{'value': 53}]  ACCT
# 5   103  [{'value': 17}]  ACWR
# 6   104  [{'value': 15}]  ACWR
# 7   100  [{'value': 26}]  ALIS
# 8   106  [{'value': 16}]  ACWR
# 9   201   [{'value': 7}]  ARBC

# %%
len(df2)
# Out:
# 383

# %%
df2['value']=0

# %%
df2.head(10)
# Out:
#    Code             data  name  value
# 0   321  [{'value': 22}]  ACCT      0
# 1   501   [{'value': 8}]  ACCT      0
# 2   101  [{'value': 20}]  ACWR      0
# 3   201  [{'value': 94}]  ACCT      0
# 4   202  [{'value': 53}]  ACCT      0
# 5   103  [{'value': 17}]  ACWR      0
# 6   104  [{'value': 15}]  ACWR      0
# 7   100  [{'value': 26}]  ALIS      0
# 8   106  [{'value': 16}]  ACWR      0
# 9   201   [{'value': 7}]  ARBC      0

# %%
for i in range(0, 382):
    df2['value'][i] = df2['data'][i][0]['value']
# Out:
# C:\Users\Public\Empty\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2 = df2.drop('data', 1)

# %%
df2.head(10)
# Out:
#    Code  name  value
# 0   321  ACCT     22
# 1   501  ACCT      8
# 2   101  ACWR     20
# 3   201  ACCT     94
# 4   202  ACCT     53
# 5   103  ACWR     17
# 6   104  ACWR     15
# 7   100  ALIS     26
# 8   106  ACWR     16
# 9   201  ARBC      7

# %%
df2['data'] = ''

# %%
for i in range(0, len(df2)):
    df2['data'][i] = {'name': df2['Code'][i], 'value': df2['value'][i]}
# Out:
# C:\Users\Public\Empty\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2 = df2.drop('Code', 1)
df2 = df2.drop('value', 1)
df2.head(10)
# Out:
#    name                        data
# 0  ACCT  {'name': 321, 'value': 22}
# 1  ACCT   {'name': 501, 'value': 8}
# 2  ACWR  {'name': 101, 'value': 20}
# 3  ACCT  {'name': 201, 'value': 94}
# 4  ACCT  {'name': 202, 'value': 53}
# 5  ACWR  {'name': 103, 'value': 17}
# 6  ACWR  {'name': 104, 'value': 15}
# 7  ALIS  {'name': 100, 'value': 26}
# 8  ACWR  {'name': 106, 'value': 16}
# 9  ARBC   {'name': 201, 'value': 7}

# %%
for i in range(0, len(df2)):
    for j in range(0, len(df)):
        if ( df2['name'][i] ==  df['name'][j]):
            df['data'][j].append(df2['data'][i])

# %%
df.head(66)
# Out:
#     name                                               data
# 0   ACCT  [{'name': 321, 'value': 22}, {'name': 501, 'va...
# 1   ACWR  [{'name': 101, 'value': 20}, {'name': 103, 'va...
# 2   ALIS                       [{'name': 100, 'value': 26}]
# 3   ARBC  [{'name': 201, 'value': 7}, {'name': 202, 'val...
# 4   ARHA  [{'name': 201, 'value': 19}, {'name': 315, 'va...
# 5   ARTS  [{'name': 201, 'value': 68}, {'name': 350, 'va...
# 6   ASIU  [{'name': 100, 'value': 7}, {'name': 102, 'val...
# 7   BUSA                       [{'name': 499, 'value': 23}]
# 8   CHBI  [{'name': 201, 'value': 21}, {'name': 300, 'va...
# 9   CHEM  [{'name': 101, 'value': 17}, {'name': 103, 'va...
# 10  CHIN                        [{'name': 202, 'value': 4}]
# 11  CMKT                       [{'name': 501, 'value': 38}]
# 12  CMSE                       [{'name': 501, 'value': 21}]
# 13  COMM                       [{'name': 202, 'value': 13}]
# 14  COMP  [{'name': 110, 'value': 31}, {'name': 111, 'va...
# 15  CPAP                       [{'name': 100, 'value': 93}]
# 16  CSHS  [{'name': 504, 'value': 26}, {'name': 557, 'va...
# 17  DASC  [{'name': 501, 'value': 35}, {'name': 521, 'va...
# 18  DTES                       [{'name': 551, 'value': 23}]
# 19  ECIR  [{'name': 313, 'value': 36}, {'name': 410, 'va...
# 20  ECON  [{'name': 100, 'value': 58}, {'name': 101, 'va...
# 21  EFIN  [{'name': 301, 'value': 44}, {'name': 403, 'va...
# 22   ELC  [{'name': 3525, 'value': 13}, {'name': 3526, '...
# 23  ELEC  [{'name': 198, 'value': 25}, {'name': 202, 'va...
# 24  ENGR  [{'name': 200, 'value': 31}, {'name': 400, 'va...
# 25  EQUR                       [{'name': 121, 'value': 15}]
# 26  ETHC  [{'name': 105, 'value': 27}, {'name': 109, 'va...
# 27  EXCH                       [{'name': 301, 'value': 12}]
# 28  FREN  [{'name': 201, 'value': 5}, {'name': 202, 'val...
# 29  GERM  [{'name': 201, 'value': 10}, {'name': 301, 'va...
# ..   ...                                                ...
# 36  ITAL  [{'name': 201, 'value': 11}, {'name': 301, 'va...
# 37  LANG                        [{'name': 290, 'value': 8}]
# 38  LATN                       [{'name': 401, 'value': 29}]
# 39   LAW  [{'name': 111, 'value': 17}, {'name': 201, 'va...
# 40  LITR  [{'name': 101, 'value': 6}, {'name': 201, 'val...
# 41  MASE  [{'name': 510, 'value': 30}, {'name': 515, 'va...
# 42  MATH  [{'name': 101, 'value': 58}, {'name': 102, 'va...
# 43  MAVA  [{'name': 205, 'value': 2}, {'name': 206, 'val...
# 44  MBGE  [{'name': 200, 'value': 7}, {'name': 300, 'val...
# 45  MECH  [{'name': 201, 'value': 38}, {'name': 203, 'va...
# 46  MEDI  [{'name': 101, 'value': 31}, {'name': 110, 'va...
# 47  MFIN  [{'name': 202, 'value': 63}, {'name': 662, 'va...
# 48  MGIS                       [{'name': 301, 'value': 24}]
# 49  MGMT  [{'name': 335, 'value': 2}, {'name': 351, 'val...
# 50  MKTG  [{'name': 302, 'value': 35}, {'name': 551, 'va...
# 51  NURS                       [{'name': 101, 'value': 18}]
# 52  OPSM  [{'name': 501, 'value': 38}, {'name': 302, 'va...
# 53  PHIL  [{'name': 101, 'value': 22}, {'name': 213, 'va...
# 54  PHYS  [{'name': 101, 'value': 5}, {'name': 102, 'val...
# 55  PSYC  [{'name': 100, 'value': 42}, {'name': 201, 'va...
# 56  QMBU  [{'name': 301, 'value': 14}, {'name': 310, 'va...
# 57  RUSS  [{'name': 201, 'value': 10}, {'name': 202, 'va...
# 58  SCIE  [{'name': 103, 'value': 10}, {'name': 108, 'va...
# 59  SOCI  [{'name': 100, 'value': 8}, {'name': 211, 'val...
# 60  SOSC  [{'name': 105, 'value': 7}, {'name': 110, 'val...
# 61  SPAN  [{'name': 201, 'value': 6}, {'name': 202, 'val...
# 62  TECH                       [{'name': 514, 'value': 16}]
# 63  TLIT  [{'name': 202, 'value': 1}, {'name': 240, 'val...
# 64  TURK  [{'name': 201, 'value': 13}, {'name': 300, 'va...
# 65  UNIV                        [{'name': 121, 'value': 0}]
#
# [66 rows x 2 columns]

# %%
len(df)
# Out:
# 66

# %%
df['data'][14]
# Out:
# [{'name': 110, 'value': 31},
#  {'name': 111, 'value': 5},
#  {'name': 130, 'value': 19},
#  {'name': 131, 'value': 76},
#  {'name': 198, 'value': 12},
#  {'name': 303, 'value': 43},
#  {'name': 317, 'value': 26},
#  {'name': 442, 'value': 31},
#  {'name': 450, 'value': 34},
#  {'name': 550, 'value': 34},
#  {'name': 551, 'value': 26}]

# %%
df.to_json (r'bubble_data.json', orient='records')
